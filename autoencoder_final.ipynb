# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, f1_score

def dataframe_from_csv(target):
    return pd.read_csv(target).rename(columns=lambda x: x.strip())

def dataframe_from_csvs(targets):
    return pd.concat([dataframe_from_csv(x) for x in targets])

# 데이터 읽기
TRAIN_FILES = sorted([x for x in Path("/content/drive/MyDrive/sj/train/").glob("*.csv")])
TEST_FILES = sorted([x for x in Path("/content/drive/MyDrive/sj/test/").glob("*.csv")])
TRAIN_DF_RAW = dataframe_from_csvs(TRAIN_FILES)
TEST_DF_RAW = dataframe_from_csvs(TEST_FILES)

# 공격 레이블 제거
ATTACK_DF = TEST_DF_RAW['attack']
DROP_FIELD = ["time", "attack_P1", "attack_P2", "attack_P3", "attack"]
VALID_COLUMNS_IN_TRAIN_DATASET = TRAIN_DF_RAW.columns.drop(DROP_FIELD)

# 데이터 정규화
scaler = StandardScaler()
TRAIN_DF = scaler.fit_transform(TRAIN_DF_RAW[VALID_COLUMNS_IN_TRAIN_DATASET])
TEST_DF = scaler.transform(TEST_DF_RAW[VALID_COLUMNS_IN_TRAIN_DATASET])

# 슬라이딩 윈도우 함수 정의
def create_sliding_windows(data, window_size):
    windows = []
    for i in range(len(data) - window_size + 1):
        windows.append(data[i:i + window_size])
    return np.array(windows)

# 윈도우 크기 설정
window_size = 50

# 슬라이딩 윈도우 적용
TRAIN_WINDOWS = create_sliding_windows(TRAIN_DF, window_size)
TEST_WINDOWS = create_sliding_windows(TEST_DF, window_size)

# 오토인코더 모델 정의 (모델 복잡도 증가)
input_dim = TRAIN_WINDOWS.shape[1] * TRAIN_WINDOWS.shape[2]
hidden_dim = 256
code_dim = 64

input_layer = Input(shape=(input_dim,))
hidden_1 = Dense(hidden_dim, activation='relu')(input_layer)
hidden_1 = Dropout(0.3)(hidden_1)  # Dropout 추가
code = Dense(code_dim, activation='relu')(hidden_1)
hidden_2 = Dense(hidden_dim, activation='relu')(code)
hidden_2 = Dropout(0.3)(hidden_2)  # Dropout 추가
output_layer = Dense(input_dim, activation='sigmoid')(hidden_2)

autoencoder = Model(inputs=input_layer, outputs=output_layer)
optimizer = Adam(learning_rate=0.00001)  # 학습률 낮춤
autoencoder.compile(optimizer=optimizer, loss='mse')

# 데이터셋을 훈련 및 검증으로 분리
train_data, val_data = train_test_split(TRAIN_WINDOWS.reshape(-1, input_dim), test_size=0.2, random_state=42)

# 오토인코더 모델 훈련
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = autoencoder.fit(train_data, train_data,
                          epochs=100,  # 에포크 증가
                          batch_size=64,  # 배치 사이즈 증가
                          shuffle=True,
                          validation_data=(val_data, val_data),
                          verbose=1,
                          callbacks=[early_stopping])

# 훈련 과정 시각화 (옵션)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# 테스트 데이터셋 예측
TEST_WINDOWS_FLATTENED = TEST_WINDOWS.reshape(-1, input_dim)
reconstructed = autoencoder.predict(TEST_WINDOWS_FLATTENED)

# 재구성 오차 계산
mse = np.mean(np.power(TEST_WINDOWS_FLATTENED - reconstructed, 2), axis=1)

# 임계값 최적화 (F1 스코어 기준)
best_threshold = 0
best_f1 = 0

for threshold in np.linspace(np.min(mse), np.max(mse), 100):
    anomalies = mse > threshold
    anomalies = anomalies.astype(int)
    score = f1_score(ATTACK_DF.values[window_size // 2: -window_size // 2 + 1], anomalies)
    if score > best_f1:
        best_f1 = score
        best_threshold = threshold

print(f'Best Threshold: {best_threshold}')
print(f'Best F1 Score: {best_f1}')

# 최적 임계값으로 이상 탐지
anomalies = mse > best_threshold
anomalies = anomalies.astype(int)

# 결과 시각화
plt.figure(figsize=(10, 6))
plt.plot(mse, label='Reconstruction Error')
plt.hlines(best_threshold, xmin=0, xmax=len(mse), colors='r', label='Threshold')
plt.legend()
plt.show()

# 공격 레이블과 비교
attack_labels = ATTACK_DF.values[window_size // 2: -window_size // 2 + 1]

print(confusion_matrix(attack_labels, anomalies))
print(classification_report(attack_labels, anomalies))
# Out:
# Epoch 1/100
# 6885/6885 [==============================] - 71s 10ms/step - loss: 0.6485 - val_loss: 0.5582
# Epoch 2/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5586 - val_loss: 0.5370
# Epoch 3/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5422 - val_loss: 0.5302
# Epoch 4/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5367 - val_loss: 0.5276
# Epoch 5/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5334 - val_loss: 0.5252
# Epoch 6/100
# 6885/6885 [==============================] - 65s 10ms/step - loss: 0.5309 - val_loss: 0.5233
# Epoch 7/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5290 - val_loss: 0.5220
# Epoch 8/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5277 - val_loss: 0.5212
# Epoch 9/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5267 - val_loss: 0.5206
# Epoch 10/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5259 - val_loss: 0.5201
# Epoch 11/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5253 - val_loss: 0.5197
# Epoch 12/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5246 - val_loss: 0.5192
# Epoch 13/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5241 - val_loss: 0.5188
# Epoch 14/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5236 - val_loss: 0.5185
# Epoch 15/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5232 - val_loss: 0.5182
# Epoch 16/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5228 - val_loss: 0.5180
# Epoch 17/100
# 6885/6885 [==============================] - 67s 10ms/step - loss: 0.5225 - val_loss: 0.5178
# Epoch 18/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5222 - val_loss: 0.5176
# Epoch 19/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5219 - val_loss: 0.5175
# Epoch 20/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5216 - val_loss: 0.5173
# Epoch 21/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5214 - val_loss: 0.5172
# Epoch 22/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5212 - val_loss: 0.5170
# Epoch 23/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5209 - val_loss: 0.5169
# Epoch 24/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5207 - val_loss: 0.5168
# Epoch 25/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5205 - val_loss: 0.5166
# Epoch 26/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5204 - val_loss: 0.5165
# Epoch 27/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5202 - val_loss: 0.5164
# Epoch 28/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5200 - val_loss: 0.5163
# Epoch 29/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5198 - val_loss: 0.5162
# Epoch 30/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5197 - val_loss: 0.5161
# Epoch 31/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5195 - val_loss: 0.5160
# Epoch 32/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5194 - val_loss: 0.5159
# Epoch 33/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5192 - val_loss: 0.5158
# Epoch 34/100
# 6885/6885 [==============================] - 65s 10ms/step - loss: 0.5191 - val_loss: 0.5157
# Epoch 35/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5190 - val_loss: 0.5156
# Epoch 36/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5188 - val_loss: 0.5155
# Epoch 37/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5187 - val_loss: 0.5154
# Epoch 38/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5186 - val_loss: 0.5153
# Epoch 39/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5185 - val_loss: 0.5153
# Epoch 40/100
# 6885/6885 [==============================] - 67s 10ms/step - loss: 0.5184 - val_loss: 0.5152
# Epoch 41/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5183 - val_loss: 0.5152
# Epoch 42/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5182 - val_loss: 0.5151
# Epoch 43/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5181 - val_loss: 0.5150
# Epoch 44/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5180 - val_loss: 0.5150
# Epoch 45/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5179 - val_loss: 0.5149
# Epoch 46/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5178 - val_loss: 0.5149
# Epoch 47/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5177 - val_loss: 0.5148
# Epoch 48/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5176 - val_loss: 0.5148
# Epoch 49/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5176 - val_loss: 0.5147
# Epoch 50/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5175 - val_loss: 0.5147
# Epoch 51/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5174 - val_loss: 0.5146
# Epoch 52/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5174 - val_loss: 0.5146
# Epoch 53/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5173 - val_loss: 0.5146
# Epoch 54/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5172 - val_loss: 0.5145
# Epoch 55/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5172 - val_loss: 0.5145
# Epoch 56/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5171 - val_loss: 0.5145
# Epoch 57/100
# 6885/6885 [==============================] - 65s 10ms/step - loss: 0.5170 - val_loss: 0.5144
# Epoch 58/100
# 6885/6885 [==============================] - 65s 10ms/step - loss: 0.5170 - val_loss: 0.5144
# Epoch 59/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5169 - val_loss: 0.5144
# Epoch 60/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5169 - val_loss: 0.5143
# Epoch 61/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5168 - val_loss: 0.5143
# Epoch 62/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5168 - val_loss: 0.5143
# Epoch 63/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5167 - val_loss: 0.5143
# Epoch 64/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5167 - val_loss: 0.5142
# Epoch 65/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5166 - val_loss: 0.5142
# Epoch 66/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5166 - val_loss: 0.5141
# Epoch 67/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5165 - val_loss: 0.5141
# Epoch 68/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5165 - val_loss: 0.5141
# Epoch 69/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5165 - val_loss: 0.5141
# Epoch 70/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5164 - val_loss: 0.5140
# Epoch 71/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5164 - val_loss: 0.5140
# Epoch 72/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5163 - val_loss: 0.5140
# Epoch 73/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5163 - val_loss: 0.5140
# Epoch 74/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5162 - val_loss: 0.5139
# Epoch 75/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5162 - val_loss: 0.5139
# Epoch 76/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5162 - val_loss: 0.5139
# Epoch 77/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5161 - val_loss: 0.5138
# Epoch 78/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5161 - val_loss: 0.5138
# Epoch 79/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5160 - val_loss: 0.5138
# Epoch 80/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5160 - val_loss: 0.5137
# Epoch 81/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5159 - val_loss: 0.5137
# Epoch 82/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5159 - val_loss: 0.5137
# Epoch 83/100
# 6885/6885 [==============================] - 67s 10ms/step - loss: 0.5159 - val_loss: 0.5137
# Epoch 84/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5158 - val_loss: 0.5137
# Epoch 85/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5158 - val_loss: 0.5136
# Epoch 86/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5158 - val_loss: 0.5136
# Epoch 87/100
# 6885/6885 [==============================] - 67s 10ms/step - loss: 0.5158 - val_loss: 0.5136
# Epoch 88/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5157 - val_loss: 0.5136
# Epoch 89/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5157 - val_loss: 0.5135
# Epoch 90/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5156 - val_loss: 0.5135
# Epoch 91/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5156 - val_loss: 0.5135
# Epoch 92/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5156 - val_loss: 0.5135
# Epoch 93/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5156 - val_loss: 0.5135
# Epoch 94/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5155 - val_loss: 0.5135
# Epoch 95/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5155 - val_loss: 0.5134
# Epoch 96/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5155 - val_loss: 0.5134
# Epoch 97/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5155 - val_loss: 0.5134
# Epoch 98/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5154 - val_loss: 0.5134
# Epoch 99/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5154 - val_loss: 0.5134
# Epoch 100/100
# 6885/6885 [==============================] - 66s 10ms/step - loss: 0.5154 - val_loss: 0.5134
# 13893/13893 [==============================] - 39s 3ms/step
# Best Threshold: 5.9142793351595655
# Best F1 Score: 0.6504668691641354
# [[426557    467]
#  [  8854   8673]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    427024
#            1       0.95      0.49      0.65     17527
#
#     accuracy                           0.98    444551
#    macro avg       0.96      0.75      0.82    444551
# weighted avg       0.98      0.98      0.98    444551
